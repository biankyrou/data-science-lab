# %% [markdown]
# ## Bora começar!
# Não sei se vocês repararam, mas esse tipo de arquivo difere dos demais arquivos desta seção. Estamos tratando da extensão '.ipynb'. <br>
# Essa extensão nos permite executar códigos em célula. Podemos também criar 'Markdown' para anotações, que é o que estou fazendo agora.

# %% [markdown]
# ## Passos a serem seguidos:
# 1- Baixe este arquivo <br>
# 2- Entre com login no site https://drive.google.com/drive/u/0/my-drive <br>
# 3- Crie uma pasta e dentro dela arraste o arquivo que você acabou de baixar. <br>
# 4- Se preferir, crie direto um arquivo 'Google Colab' dentro da pasta, assim como na imagem a seguir: <br><br>
# ![image.png](attachment:image.png)

# %% [markdown]
# Bom, agora estamos dentro de um ambiente Jupyter Notebook, ou mais precisamente, dentro do Google Colab (que nos permite executar arquivos tipo '.ipynb') <br>

# %%
# exemplo de códigoooo
frase = "Iniciando em Ciência de Dados"
print(frase)

# %% [markdown]
# Para aprender mais sobre este ambiente, acesse: https://www.youtube.com/watch?v=9Z9CsZCFsTE&ab_channel=DataICMC
